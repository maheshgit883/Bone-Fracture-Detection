# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 878.7/878.7 kB 21.5 MB/s eta 0:00:0000:01
# ...

# %%
from ultralytics import YOLO

model = YOLO("yolo11s.pt")
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100%|██████████| 18.4M/18.4M [00:00<00:00, 199MB/s]

# %%
train_results = model.train(
    data="/kaggle/input/bone-fracture-detection-images-for-yolov11/data.yaml",  
    epochs=100,  
    device=0,  
    project="/kaggle/working/runs"
)
# Out:
# Ultralytics 8.3.25 🚀 Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# ...

# %%
model = YOLO("/kaggle/working/runs/train2/weights/best.pt")

# %%
results = model("/kaggle/input/bone-fracture-detection-images-for-yolov11/train/images/distal-humeral-fractures-2-_JPEG.rf.f9442db05ec473187c60870d407c9e8f.jpg")
# Out:
# image 1/1 /kaggle/input/bone-fracture-detection-images-for-yolov11/train/images/distal-humeral-fractures-2-_JPEG.rf.f9442db05ec473187c60870d407c9e8f.jpg: 640x640 1 elbow positive, 10.6ms
# Speed: 3.3ms preprocess, 10.6ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
